# %%
import matplotlib.pyplot as plt
from skimage import io,data
from metrics.emee import emee
from metrics.contrast_pixel import contrast_img
from algorithms.edge_detection import edge_detection,space_edge_detection,parameterized_space_edge_detection

a=data.camera()
b=io.imread('CXR7_IM-2263-1001.png')

plt.imshow(a,cmap='gray',interpolation='nearest')
plt.show()
plt.imshow(b, cmap='gray', interpolation='nearest') 
plt.show()

# %%
from models.lip import LIPImage,LIPSpace
from models.hlip import HLIPImage,HLIPSpace
from models.pslip import PSLIPImage,PSLIPSpace
from models.slip import SLIPSpace
from models.plip import PLIPSpace
from models.ppslip import PPSLIPSpace

# %%
import numpy as np
from skimage.filters import sobel

# %% [markdown]
# ### Lineal

# %%
la=np.array(a.tolist())

sla=edge_detection(la,sobel)

sla=sla*255/np.max(sla)

io.imsave('sla.png',sla)

plt.imshow(sla,cmap='gray',interpolation='nearest')
plt.show()

sla=io.imread('sla.png')
print(contrast_img(sla,256,2))

lb=np.array(b.tolist())

slb=edge_detection(lb,sobel)

slb=slb*255/np.max(slb)

plt.imshow(slb,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('slb.png',slb)

slb=io.imread('slb.png')
print(contrast_img(slb,256,2))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 254.99999999999997]. Convert image to uint8 prior to saving to suppress this warning.
# 4.847371234679562
# Lossy conversion from float64 to uint8. Range [0.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# 2.9638207414739735

# %% [markdown]
# ### LIP

# %%
js=LIPSpace()

sja=js.M-space_edge_detection(a,sobel,js)

plt.imshow(sja,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('sja.png',sja)

sja=io.imread('sja.png')
print(contrast_img(sja,256,2))

sjb=js.M-space_edge_detection(b,sobel,js)

plt.imshow(sjb,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('sjb.png',sjb)

sjb=io.imread('sjb.png')
print(contrast_img(sjb,256,2))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.1190881608025]. Convert image to uint8 prior to saving to suppress this warning.
# 7.189143703749476
# Lossy conversion from float64 to uint8. Range [0.0, 255.99887038908514]. Convert image to uint8 prior to saving to suppress this warning.
# 3.5894131879369007

# %% [markdown]
# ### HLIP

# %%
hs=HLIPSpace()

sha=space_edge_detection(a,sobel,hs)

io.imsave('sha.png',sha)

sha=io.imread('sha.png')
print(contrast_img(sha,256,2))

plt.imshow(sha,cmap='gray',interpolation='nearest')
plt.show()

shb=space_edge_detection(b,sobel,hs)

plt.imshow(shb,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('shb.png',shb)

shb=io.imread('shb.png')
print(contrast_img(shb,256,2))
# Out:
# Lossy conversion from float64 to uint8. Range [128.0, 255.1509642852705]. Convert image to uint8 prior to saving to suppress this warning.
# 7.791480216594329
# Lossy conversion from float64 to uint8. Range [128.0, 255.99917972806657]. Convert image to uint8 prior to saving to suppress this warning.
# 4.291278621191445

# %% [markdown]
# ### PSLIP

# %%
pss=PSLIPSpace()

spsa=space_edge_detection(a,sobel,pss)

io.imsave('spsa.png',spsa)

spsa=io.imread('spsa.png')
print(contrast_img(spsa,256,2))

plt.imshow(spsa,cmap='gray',interpolation='nearest')
plt.show()

spsb=space_edge_detection(b,sobel,pss)

plt.imshow(spsb,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('spsb.png',spsb)

spsb=io.imread('spsb.png')
print(contrast_img(spsb,256,2))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 254.72567800117767]. Convert image to uint8 prior to saving to suppress this warning.
# 9.054213195085746
# Lossy conversion from float64 to uint8. Range [0.0, 219.23912542776114]. Convert image to uint8 prior to saving to suppress this warning.
# 9.59747746680444

# %% [markdown]
# ## SLIP

# %%
ss=SLIPSpace()

ssa=space_edge_detection(a,sobel,ss)

plt.imshow(ssa,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('ssa.png',ssa)

ssa=io.imread('ssa.png')
print(contrast_img(ssa,256,2))

ssb=space_edge_detection(b,sobel,ss)

plt.imshow(ssb,cmap='gray',interpolation='nearest')
plt.show()

io.imsave('ssb.png',ssb)

ssb=io.imread('ssb.png')
print(contrast_img(ssb,256,2))
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 250.38218283234875]. Convert image to uint8 prior to saving to suppress this warning.
# 6.045634252616894
# Lossy conversion from float64 to uint8. Range [0.0, 123.60448573630984]. Convert image to uint8 prior to saving to suppress this warning.
# 6.881181470922099

# %% [markdown]
# # PLIP

# %%
mus=[256,400,500,800,1000,1026,4100,600,300]

ps=PLIPSpace()

lambd=256

pa=ps.function(ps.gray_tone(a),lambd)

aux=ps.inverse_function(sobel(pa),lambd)

d_1 = 4 if pa.shape[0]%4==0 else 5
d_2 = 4 if pa.shape[1]%4==0 else 5

max_emee=-1
max_mu=-1

for mu in mus:
    max_pi_r=np.max(aux)
    if mu < max_pi_r:
        continue
    result=mu-ps.inverse_gray_tone(aux,mu)
    actual_emee=emee(result,1,d_1,d_2,0.5)
    if actual_emee > max_emee:
        max_emee=actual_emee
        max_mu=mu

spa=max_mu-ps.inverse_gray_tone(aux,max_mu)
print(max_emee)
print(max_mu)

io.imsave('spa.png',spa)
spa=io.imread('spa.png')
print(contrast_img(spa,256,2))
plt.imshow(spa,cmap='gray',interpolation='nearest')
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.11908816080245]. Convert image to uint8 prior to saving to suppress this warning.
# 41.67238990771067
# 1026
# 7.189143703749476

# %%
mus=[256,400,500,800,1000,1026,4100,600,300]

ps=PLIPSpace()

lambd=256

pb=ps.function(ps.gray_tone(b),lambd)

aux=ps.inverse_function(sobel(pb),lambd)

d_1 = 4 if pb.shape[0]%4==0 else 5
d_2 = 4 if pb.shape[1]%4==0 else 5

max_emee=-1
max_mu=-1

for mu in mus:
    max_pi_r=np.max(aux)
    if mu < max_pi_r:
        continue
    result=mu-ps.inverse_gray_tone(aux,mu)
    actual_emee=emee(result,1,d_1,d_2,0.5)
    if actual_emee > max_emee:
        max_emee=actual_emee
        max_mu=mu

spb=max_mu-ps.inverse_gray_tone(aux,max_mu)
print(max_emee)
print(max_mu)

io.imsave('spb.png',spb)
spb=io.imread('spb.png')
print(contrast_img(spb,256,2))
plt.imshow(spb,cmap='gray',interpolation='nearest')
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.9988703890849]. Convert image to uint8 prior to saving to suppress this warning.
# 71.51233259073564
# 4100
# 3.5894131879369007

# %% [markdown]
# # PPSLIP

# %%
lambd=256

ppss=PPSLIPSpace()

sppsa=parameterized_space_edge_detection(a,sobel,ppss,lambd=lambd)

io.imsave('sppsa.png',sppsa)
sppsa=io.imread('sppsa.png')
print(contrast_img(sppsa,256,2))
plt.imshow(sppsa,cmap='gray',interpolation='nearest')
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 254.72567800117767]. Convert image to uint8 prior to saving to suppress this warning.
# 9.054213195085746

# %%
lambd=256

ppss=PPSLIPSpace()

sppsb=parameterized_space_edge_detection(b,sobel,ppss,lambd=lambd)

io.imsave('sppsb.png',sppsb)
sppsb=io.imread('sppsb.png')
print(contrast_img(sppsb,256,2))
plt.imshow(sppsb,cmap='gray',interpolation='nearest')
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 219.23912542776114]. Convert image to uint8 prior to saving to suppress this warning.
# 9.59747746680444

# %% [markdown]
# ## PLIP Function

# %%
lambd=256
mu=256

ps=PLIPSpace()

spa=mu-parameterized_space_edge_detection(a,sobel,ps,lambd=lambd,mu=mu)

io.imsave('spa.png',spa)
spa=io.imread('spa.png')
print(contrast_img(spa,256,2))
plt.imshow(spa,cmap='gray',interpolation='nearest')
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.1190881608025]. Convert image to uint8 prior to saving to suppress this warning.
# 7.189143703749476

# %%
lambd=256
mu=256

ps=PLIPSpace()

spb=mu-parameterized_space_edge_detection(b,sobel,ps,lambd=lambd,mu=mu)

io.imsave('spb.png',spb)
spb=io.imread('spb.png')
print(contrast_img(spb,256,2))
plt.imshow(spb,cmap='gray',interpolation='nearest')
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 255.99887038908514]. Convert image to uint8 prior to saving to suppress this warning.
# 3.5894131879369007
